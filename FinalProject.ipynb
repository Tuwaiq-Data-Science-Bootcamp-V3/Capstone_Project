# %%
#pip install --upgrade pip setuptools wheel

# %%
#pip install opencv-python

# %%
#pip install opencv-python==3.4.13.47

# %%
#pip install --upgrade pip setuptools wheel

# %%
#pip install cvzone

# %%
##pip install yolo

# %%
#from Ultralytics import YOLO

# %%
#pip install ultralytics-yolov5

# %%
#pip install ultralytics

# %%
#pip install ultralytics --proxy localhost:8892

# %%
from ultralytics import YOLO

# %%
#downloading weights n means nano
#gives smoother webcam performance
#YOU WILL GET ERROR, PUT 'yolov5n.pt' ONLY ON THE PATH
model=YOLO(r'C:\Users\fai-w\Desktop\weights\best.pt')
#yolov8l.pt -> webcam gets laggy

# %%
#to stop mage from closing when preprocessng is complete
import cv2

# %%
#!yolo task=detect mode=train model=yolov5n.pt data=c:\Users\fai-w\datasetFinal\data.yaml

# %%
#show results of image then closes image
results=model(r"C:\Users\fai-w\Desktop\download.jpg", show=True)
#keeps image open
cv2.waitKey(0)
cv2.destroyAllWindows()
results
# Out:
# image 1/1 C:\Users\fai-w\Desktop\download.jpg: 640x640 1 Jacket, 154.1ms
# Speed: 6.0ms preprocess, 154.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Hoodie', 1: 'Jacket', 2: 'Mid-lenght dress', 3: 'Pants', 4: 'Tshirt', 5: 'dress', 6: 'skirt'}
#  orig_img: array([[[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         ...,
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]]], dtype=uint8)
#  orig_shape: (263, 263)
#  path: 'C:\\Users\\fai-w\\Desktop\\download.jpg'
#  probs: None
#  speed: {'preprocess': 5.983591079711914, 'inference': 154.06227111816406, 'postprocess': 0.9980201721191406}]

# %%
#for r in results:
#        boxes=r.boxes
#        #get Xs and Ys of each box
#        for box in boxes:
#            x1, y1, x2, y2 = box.xyxy[0]
#            print(x1, y1, x2, y2)
#IDEA USE BETTER ACCURACY WHEN PEOPLE WANT TO UPLOAD AN IMAGE 
#BUT IN REALTIME OBJECT DETECTION GET WORSE WEIGHT BUT ADJUST MANUALLY

# %%
import pandas as pd
import numpy as np

#colorss=pd.read_csv('D:\color_names.csv')

# %%
#pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0
#      ---------------------------------- - 399.4/422.5 kB 958.4 kB/s eta 0:00:01
#      ------------------------------------ 422.5/422.5 kB 943.3 kB/s eta 0:00:00
# Requirement already satisfied: jinja2 in d:\anacnda3\envs\cudaenv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in d:\anacnda3\envs\cudaenv\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in d:\anacnda3\envs\cudaenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ------------------- -------------------- 30.7/62.7 kB ? eta -:--:--
#      ---------------------------------------- 62.7/62.7 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in d:\anacnda3\envs\cudaenv\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anacnda3\envs\cudaenv\lib\site-packages (from pandas<3,>=0.25->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in d:\anacnda3\envs\cudaenv\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anacnda3\envs\cudaenv\lib\site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anacnda3\envs\cudaenv\lib\site-packages (from requests<3,>=2.4->streamlit) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anacnda3\envs\cudaenv\lib\site-packages (from requests<3,>=2.4->streamlit) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anacnda3\envs\cudaenv\lib\site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.15.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/87.5 kB 1.9 MB/s eta 0:00:01
#      ------------------------------- ------ 71.7/87.5 kB 975.2 kB/s eta 0:00:01
#      -------------------------------------- 87.5/87.5 kB 709.1 kB/s eta 0:00:00
# Collecting tzdata
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anacnda3\envs\cudaenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19591 sha256=a4daa61db75ddff08939b285ab163db7a1b398d7eb81cfa30916ad5034cfccd5
#   Stored in directory: c:\users\fai-w\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: validators, tzdata, smmap, pympler, protobuf, mdurl, cachetools, blinker, pytz-deprecation-shim, pydeck, markdown-it-py, gitdb, tzlocal, rich, gitpython, altair, streamlit
# Successfully installed altair-5.0.1 blinker-1.6.2 cachetools-5.3.1 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.23.3 pydeck-0.8.1b0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.4.2 smmap-5.0.0 streamlit-1.23.1 tzdata-2023.3 tzlocal-4.3 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
 
# Title
st.title("Hello GeeksForGeeks !!!")
# Out:
# 2023-06-20 19:48:59.688
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run D:\anacnda3\envs\cudaenv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
#colorss.info()

# %%
#####TESTINGGGG#############
#importing cvzone to show detections
import cvzone
import numpy as np
#webcam object
cam=cv2.VideoCapture(0)
#width
cam.set(3, 1280)
#height
cam.set(4, 720)

#LOWER AND UPPER RANGE OF MULTIPLE COLORS

lower_black = np.array([0,0,0])
upper_black = np.array([250,255,30])

lower_white = np.array([0,0,255])
upper_white = np.array([0,0,255])

lower_red = np.array([0,150,50])
upper_red = np.array([10,255,255])

lower_green = np.array([45,150,50])
upper_green = np.array([65,255,255])

lower_yellow = np.array([25,150,50])
upper_yellow = np.array([35,255,255])

lower_light_blue = np.array([95,150,0])
upper_light_blue = np.array([110,255,255])

lower_orange = np.array([15,150,0])
upper_orange = np.array([25,255,255])

lower_dark_pink = np.array([160,150,0])
upper_dark_pink = np.array([170,255,255])

lower_pink = np.array([145,150,0])
upper_pink = np.array([155,255,255])

lower_cyan = np.array([85,150,0])
upper_cyan = np.array([95,255,255])

lower_dark_blue = np.array([115,150,0])
upper_dark_blue = np.array([125,255,255])

#purple
lower_purple = np.array([129, 50, 70])
#np.array([129, 50, 70])138,43,226
upper_purple = np.array([158, 255, 255])
#np.array([158, 255, 255])255,0,255
#light purple
#upper_light_purple = np.array([220,208,255])
#lower_light_purple = np.array([181,126,220])
#dark purple
#upper_dark_purple = np.array([145,92,131])
#lower_dark_purple = np.array([50,23,77])


#turqise
lower_turq = np.array([0,206,209])
upper_turq = np.array([175,238,238])



#TO KEEP THE WEBCAM RUNNING
while True:
    #IF CAM IS FOUND, SAVE IT TO "img"
    success, img = cam.read()
    #YOLO MODEL RESULTS
    results=model(img, stream=True)
    #CAPTURE COLORS AND TURN THEM TO "HSV" VALUES
    imgC = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #range of colors
    yellow = cv2.inRange(imgC, lower_yellow, upper_yellow)
    red = cv2.inRange(imgC, lower_red, upper_red)
    dblue = cv2.inRange(imgC, lower_dark_blue, upper_dark_blue)
    green = cv2.inRange(imgC, lower_green, upper_green)
    pink = cv2.inRange(imgC, lower_pink, upper_pink)
    lblue = cv2.inRange(imgC, lower_light_blue, upper_light_blue)
    purple = cv2.inRange(imgC, lower_purple, upper_purple)
    orange = cv2.inRange(imgC, lower_orange, upper_orange)
    cyan = cv2.inRange(imgC, lower_cyan, upper_cyan)
    turq = cv2.inRange(imgC, lower_turq, upper_turq)
    
    #lpurple = cv2.inRange(imgC, lower_light_purple, upper_light_purple)
    #dpurple = cv2.inRange(imgC, lower_dark_purple, upper_dark_purple)
    #morphological transformation and dilation
    #kernal=np.ones((5,5), 'uint8')
    #red=cv2.dilate(red, kernal)
    #resr=cv2.bitwise_and(img, img, mask = red)
    #blue=cv2.dilate(blue, kernal)
    #resb=cv2.bitwise_and(img, img, mask = blue)
    #yellow=cv2.dilate(yellow, kernal)
    #resy=cv2.bitwise_and(img, img, mask = red)
    
    #tracking colors
    (contours, hierarchy)=cv2.findContours(red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'red', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    
    #BLUE
    (contours, hierarchy)=cv2.findContours(dblue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'dark blue', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #YELLOW
    (contours, hierarchy)=cv2.findContours(yellow, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
            
    #green
    (contours, hierarchy)=cv2.findContours(green, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'green', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #pink
    (contours, hierarchy)=cv2.findContours(pink, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'pink', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #lblue
    (contours, hierarchy)=cv2.findContours(lblue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'light blue', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    
    #purple
    (contours, hierarchy)=cv2.findContours(purple, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'purple', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #ORANGE
    (contours, hierarchy)=cv2.findContours(orange, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'orange', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #CYAN
    (contours, hierarchy)=cv2.findContours(cyan, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'cyan', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
            
    #TURQ
    (contours, hierarchy)=cv2.findContours(turq, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'turq', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #cv2.imshow('mask', mask)
    #cv2.imshow('mask', mask)
    
    #cv2.imshow('mask', mask)
    #contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    #if len(contour)!=0:
    #    for cont in contour:
    #        if cv2.contourArea(cont)>1000:
    #            x, y, w, h=cv2.boundingRect(cont)
    #            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 3)
    #            cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (251,255,255), 2)
    #cam.set(CV_CAP_PROP_BUFFERSIZE, 3)
    #results.boxes
    #IF CAN NOT THERE
    if not cam.isOpened():
        print('Unable to load camera.')
        sleep(5)
        pass
    #FOR CAPTURING BOUNDRIES OF THE YOLO PREDICTIONS 
    # Capture frame-by-frame
    ret, frame = cam.read()
    #end of extra
    #loop through every frame
    for r in results:
        boxes=r.boxes
        #get Xs and Ys of each box
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            print(x1, y1, x2, y2)
    #cv2.imshow("image", img)
    #TO QUIT WEBCAM, PRESS "q" (SOMETIMES YOU HAVE TO HOLD IT AND OTHER TIMES YOU CAN JUST PRESS IT)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Jacket, 126.7ms
# Speed: 3.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# tensor(413.1975) tensor(382.2365) tensor(803.2441) tensor(714.9299)
# 0: 384x640 1 Hoodie, 1 Jacket, 144.6ms
# Speed: 3.0ms preprocess, 144.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Jacket, 103.4ms
# tensor(401.2338) tensor(389.4643) tensor(995.2722) tensor(716.3684)
# tensor(966.0951) tensor(203.1566) tensor(1280.) tensor(717.4777)
# tensor(404.3114) tensor(401.9263) tensor(1225.8459) tensor(716.1241)
# Speed: 4.0ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Hoodie, 1 Jacket, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1
4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 109.3ms
# Speed: 3.1ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 101.3ms
# Speed: 3.0ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 128.7ms
# Speed: 3.0ms preprocess, 128.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Jacket, 108.5ms
# Speed: 4.0ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 Hoodies, 1 Jacket, 95.1ms
# tensor(349.6423) tensor(366.1492) tensor(1089.3542) tensor(713.4287)
# tensor(357.4632) tensor(362.1148) tensor(895.3390) tensor(713.5657)
# tensor(945.3494) tensor(185.8237) tensor(1280.) tensor(718.4428)
# tensor(1076.0990) tensor(156.6309) tensor(1279.9957) tensor(720.)
# Speed: 3.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 110.2ms
# Speed: 3.1ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Jacket, 106.1ms
# Speed: 3.1ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 Hoodies, 96.4ms
# tensor(357.8581) tensor(365.7866) tensor(843.6382) tensor(713.4063)
# tensor(358.2945) tensor(370.3957) tensor(846.9553) tensor(713.3107)
# tensor(932.1776) tensor(188.1539) tensor(1280.) tensor(718.1423)
# tensor(1056.8531) tensor(177.7568) tensor(1280.) tensor(720.)
# Speed: 2.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 Hoodies, 1 Jacket, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Jacket, 90.1ms
# tensor(937.9224) tensor(178.1392) tensor(1280.) tensor(718.0758)
# tensor(362.9749) tensor(376.6330) tensor(839.6980) tensor(713.1552)
# tensor(1098.3379) tensor(154.1040) tensor(1279.9458) tensor(720.)
# tensor(362.5595) tensor(376.6778) tensor(844.6827) tensor(713.1160)
# tensor(360.5646) tensor(366.4030) tensor(856.3649) tensor(713.5144)
# Speed: 2.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Hoodie, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 Jacket, 100.3ms
# tensor(358.5412) tensor(366.8686) tensor(819.5534) tensor(713.3131)
# tensor(349.3428) tensor(366.6837) tensor(860.2214) tensor(714.8075)
# Speed: 2.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 118.3ms
# Speed: 2.0ms preprocess, 118.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
#importing cvzone to show detections
import cvzone
import numpy as np
#webcam object
cam=cv2.VideoCapture(0)
#width
cam.set(3, 1280)
#height
cam.set(4, 720)

#LOWER AND UPPER RANGE OF MULTIPLE COLORS

lower_black = np.array([0,0,0])
upper_black = np.array([250,255,30])

lower_white = np.array([0,0,255])
upper_white = np.array([0,0,255])

lower_red = np.array([0,150,50])
upper_red = np.array([10,255,255])

lower_green = np.array([45,150,50])
upper_green = np.array([65,255,255])

lower_yellow = np.array([25,150,50])
upper_yellow = np.array([35,255,255])

lower_light_blue = np.array([95,150,0])
upper_light_blue = np.array([110,255,255])

lower_orange = np.array([15,150,0])
upper_orange = np.array([25,255,255])

lower_dark_pink = np.array([160,150,0])
upper_dark_pink = np.array([170,255,255])

lower_pink = np.array([145,150,0])
upper_pink = np.array([155,255,255])

lower_cyan = np.array([85,150,0])
upper_cyan = np.array([95,255,255])

lower_dark_blue = np.array([115,150,0])
upper_dark_blue = np.array([125,255,255])

#purple
lower_purple = np.array([129, 50, 70])
#np.array([129, 50, 70])138,43,226
upper_purple = np.array([158, 255, 255])
#np.array([158, 255, 255])255,0,255
#light purple
#upper_light_purple = np.array([220,208,255])
#lower_light_purple = np.array([181,126,220])
#dark purple
#upper_dark_purple = np.array([145,92,131])
#lower_dark_purple = np.array([50,23,77])


#turqise
lower_turq = np.array([0,206,209])
upper_turq = np.array([175,238,238])



#TO KEEP THE WEBCAM RUNNING
while True:
    #IF CAM IS FOUND, SAVE IT TO "img"
    success, img = cam.read()
    #YOLO MODEL RESULTS
    results=model(img, stream=True)
    #CAPTURE COLORS AND TURN THEM TO "HSV" VALUES
    imgC = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #range of colors
    yellow = cv2.inRange(imgC, lower_yellow, upper_yellow)
    red = cv2.inRange(imgC, lower_red, upper_red)
    dblue = cv2.inRange(imgC, lower_dark_blue, upper_dark_blue)
    green = cv2.inRange(imgC, lower_green, upper_green)
    pink = cv2.inRange(imgC, lower_pink, upper_pink)
    lblue = cv2.inRange(imgC, lower_light_blue, upper_light_blue)
    purple = cv2.inRange(imgC, lower_purple, upper_purple)
    orange = cv2.inRange(imgC, lower_orange, upper_orange)
    cyan = cv2.inRange(imgC, lower_cyan, upper_cyan)
    turq = cv2.inRange(imgC, lower_turq, upper_turq)

    #lpurple = cv2.inRange(imgC, lower_light_purple, upper_light_purple)
    #dpurple = cv2.inRange(imgC, lower_dark_purple, upper_dark_purple)
    #morphological transformation and dilation
    #kernal=np.ones((5,5), 'uint8')
    #red=cv2.dilate(red, kernal)
    #resr=cv2.bitwise_and(img, img, mask = red)
    #blue=cv2.dilate(blue, kernal)
    #resb=cv2.bitwise_and(img, img, mask = blue)
    #yellow=cv2.dilate(yellow, kernal)
    #resy=cv2.bitwise_and(img, img, mask = red)
    
    #tracking colors
    (contours, hierarchy)=cv2.findContours(red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'red', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    
    #BLUE
    (contours, hierarchy)=cv2.findContours(dblue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'dark blue', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #YELLOW
    (contours, hierarchy)=cv2.findContours(yellow, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
            
    #green
    (contours, hierarchy)=cv2.findContours(green, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'green', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #pink
    (contours, hierarchy)=cv2.findContours(pink, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'pink', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #lblue
    (contours, hierarchy)=cv2.findContours(lblue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'light blue', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    
    #purple
    (contours, hierarchy)=cv2.findContours(purple, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'purple', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #ORANGE
   
    #CYAN
    (contours, hierarchy)=cv2.findContours(cyan, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'cyan', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
            
    #TURQ
    (contours, hierarchy)=cv2.findContours(turq, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for pic, conn in enumerate(contours):
        area=cv2.contourArea(conn)
        if(area>500):
            x, y, w, h = cv2.boundingRect(conn)
            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
            cv2.putText(img, 'turq', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
    #cv2.imshow('mask', mask)
    #cv2.imshow('mask', mask)
    
    #cv2.imshow('mask', mask)
    #contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    #if len(contour)!=0:
    #    for cont in contour:
    #        if cv2.contourArea(cont)>1000:
    #            x, y, w, h=cv2.boundingRect(cont)
    #            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 3)
    #            cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (251,255,255), 2)
    #cam.set(CV_CAP_PROP_BUFFERSIZE, 3)
    #results.boxes
    #IF CAN NOT THERE
    if not cam.isOpened():
        print('Unable to load camera.')
        sleep(5)
        pass
    #FOR CAPTURING BOUNDRIES OF THE YOLO PREDICTIONS 
    # Capture frame-by-frame
    ret, frame = cam.read()
    #end of extra
    #loop through every frame
    for r in results:
        boxes=r.boxes
        #get Xs and Ys of each box
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            print(x1, y1, x2, y2)
            (contours, hierarchy)=cv2.findContours(orange, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            for pic, conn in enumerate(contours):
                area=cv2.contourArea(conn)
                #x1. try allign to
                if(area>500):
                    x, y, w, h = cv2.boundingRect(conn)
                #if(x1<x and y1<y and x2>w and y2>h):
                    cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
                    cv2.putText(img, 'orange', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
                
    cv2.imshow("image", img)
    #TO QUIT WEBCAM, PRESS "q" (SOMETIMES YOU HAVE TO HOLD IT AND OTHER TIMES YOU CAN JUST PRESS IT)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 145.3ms
# Speed: 7.9ms preprocess, 145.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 126.4ms
# Speed: 1.7ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 127.9ms
# Speed: 3.0ms preprocess, 127.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 119.5ms
# Speed: 4.0ms preprocess, 119.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 102.7ms
# Speed: 2.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 98.1ms
# Speed: 4.0ms preprocess, 98.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 124.6ms
# Speed: 2.0ms preprocess, 124.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 104.1ms
# Speed: 1.0ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 86.6ms
# Speed: 4.3ms preprocess, 86.6ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 0.0ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 112.2ms
# Speed: 2.0ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 92.9ms
# Speed: 5.4ms preprocess, 92.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 130.5ms
# Speed: 0.0ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 128.5ms
# Speed: 3.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 117.6ms
# Speed: 4.0ms preprocess, 117.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 110.8ms
# Speed: 3.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 99.9ms
# Speed: 2.3ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 123.3ms
# Speed: 0.0ms preprocess, 123.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 106.4ms
# Speed: 2.0ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 91.2ms
# Speed: 0.0ms preprocess, 91.2ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 109.3ms
# Speed: 3.7ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 82.9ms
# Speed: 5.0ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 84.2ms
# Speed: 4.9ms preprocess, 84.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 123.5ms
# Speed: 0.0ms preprocess, 123.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 94.0ms
# Speed: 0.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 118.2ms
# Speed: 0.0ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 115.6ms
# Speed: 4.6ms preprocess, 115.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 90.6ms
# Speed: 0.0ms preprocess, 90.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 121.1ms
# Speed: 2.0ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 101.2ms
# Speed: 5.3ms preprocess, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 112.4ms
# Speed: 2.0ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 97.1ms
# Speed: 3.2ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 97.9ms
# Speed: 4.0ms preprocess, 97.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 4.4ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# حولت الأكواد القديمة لمارك أب احتياط

# %% [markdown]
# #####TESTINGGGG#############
# #importing cvzone to show detections
# import cvzone
# import numpy as np
# #webcam object
# cam=cv2.VideoCapture(0)
# #width
# cam.set(3, 1280)
# #height
# cam.set(4, 720)
#
# ####colors#####
#
# #YELLOW
# #lower range of yellow
# #yellow_lower = np.array([15, 150, 20])
# #upper range of yellow
# #yellow_upper = np.array([35, 255, 255])
# yellow_lower = np.array([15, 150, 20])
# #upper range of yellow
# yellow_upper = np.array([35, 255, 255])
# #BLUE
# #lower range of blue
# #blue_lower = np.array([99, 115, 150])
# #upper range of blue
# #blue_upper = np.array([60, 255, 255])
# blue_lower = np.array([0, 25, 125])
# #upper range of blue
# blue_upper = np.array([183, 220, 255])
# #RED
# #lower range of red
# #red_lower = np.array([136, 87, 111])
# #upper range of red
# #red_upper = np.array([180, 255, 255])
# red_lower = np.array([124, 0, 0])
# #upper range of red
# red_upper = np.array([255, 67, 67])
# #PINK
# pink_lower = np.array([164, 43, 43])
# #upper range of red
# pink_upper = np.array([255, 199, 199])
# #PURPLE
# #GREEN
# green_lower = np.array([0, 48, 20])
# #upper range of yellow
# green_upper = np.array([210, 255, 226])
#
#
# while True:
#     success, img = cam.read()
#     results=model(img, stream=True)
#     imgC = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#     #range of colors
#     yellow = cv2.inRange(imgC, yellow_lower, yellow_upper)
#     red = cv2.inRange(imgC, red_lower, red_upper)
#     blue = cv2.inRange(imgC, blue_lower, blue_upper)
#     #morphological transformation and dilation
#     #kernal=np.ones((5,5), 'uint8')
#     #red=cv2.dilate(red, kernal)
#     #resr=cv2.bitwise_and(img, img, mask = red)
#     #blue=cv2.dilate(blue, kernal)
#     #resb=cv2.bitwise_and(img, img, mask = blue)
#     #yellow=cv2.dilate(yellow, kernal)
#     #resy=cv2.bitwise_and(img, img, mask = red)
#
#     #tracking colors
#     (contours, hierarchy)=cv2.findContours(red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     for pic, conn in enumerate(contours):
#         area=cv2.contourArea(conn)
#         if(area>500):
#             x, y, w, h = cv2.boundingRect(conn)
#             cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
#             cv2.putText(img, 'red', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
#     #BLUE
#     (contours, hierarchy)=cv2.findContours(blue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     for pic, conn in enumerate(contours):
#         area=cv2.contourArea(conn)
#         if(area>500):
#             x, y, w, h = cv2.boundingRect(conn)
#             cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
#             cv2.putText(img, 'blue', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
#     #YELLOW
#     (contours, hierarchy)=cv2.findContours(yellow, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     for pic, conn in enumerate(contours):
#         area=cv2.contourArea(conn)
#         if(area>500):
#             x, y, w, h = cv2.boundingRect(conn)
#             cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 2)
#             cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (251,255,255), 2)
#
#
#     #cv2.imshow('mask', mask)
#     #contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     #if len(contour)!=0:
#     #    for cont in contour:
#     #        if cv2.contourArea(cont)>1000:
#     #            x, y, w, h=cv2.boundingRect(cont)
#     #            cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 3)
#     #            cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (251,255,255), 2)
#     #cam.set(CV_CAP_PROP_BUFFERSIZE, 3)
#     #results.boxes
#     #extra
#     if not cam.isOpened():
#         print('Unable to load camera.')
#         sleep(5)
#         pass
#
#     # Capture frame-by-frame
#     ret, frame = cam.read()
#     #end of extra
#     #loop through every frame
#     for r in results:
#         boxes=r.boxes
#         #get Xs and Ys of each box
#         for box in boxes:
#             x1, y1, x2, y2 = box.xyxy[0]
#             print(x1, y1, x2, y2)
#     #cv2.imshow("image", img)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cam.release()
# cv2.destroyAllWindows()
#     #if cv2.getWindowProperty(img, cv2.WND_PROP_VISIBLE) <1:
#         #break
# #cv2.destroyAllWindows()

# %% [markdown]
# #importing cvzone to show detections
# import cvzone
# import numpy as np
# #webcam object
# cam=cv2.VideoCapture(0)
# #width
# cam.set(3, 1280)
# #height
# cam.set(4, 720)
# #lower range of color
# lower = np.array([15, 150, 20])
# #upper range of color
# upper = np.array([35, 255, 255])
# while True:
#     success, img = cam.read()
#     results=model(img, stream=True)
#     imgC = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#     mask = cv2.inRange(imgC, lower, upper)
#     cv2.imshow('mask', mask)
#     contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if len(contour)!=0:
#         for cont in contour:
#             if cv2.contourArea(cont)>1000:
#                 x, y, w, h=cv2.boundingRect(cont)
#                 cv2.rectangle(img, (x, y), (x+w,y+h), (251, 255, 255), 3)
#                 cv2.putText(img, 'yellow', (x, y+h+10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (251,255,255), 2)
#     #cam.set(CV_CAP_PROP_BUFFERSIZE, 3)
#     #results.boxes
#     #extra
#     if not cam.isOpened():
#         print('Unable to load camera.')
#         sleep(5)
#         pass
#
#     # Capture frame-by-frame
#     ret, frame = cam.read()
#     #end of extra
#     #loop through every frame
#     for r in results:
#         boxes=r.boxes
#         #get Xs and Ys of each box
#         for box in boxes:
#             x1, y1, x2, y2 = box.xyxy[0]
#             print(x1, y1, x2, y2)
#     #cv2.imshow("image", img)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cam.release()
# cv2.destroyAllWindows()
#     #if cv2.getWindowProperty(img, cv2.WND_PROP_VISIBLE) <1:
#         #break
# #cv2.destroyAllWindows()

# %%
x1.item()
# Out:
# 320.8778076171875

# %%
#pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
#import torch
#import torchvision.models as models

# %%
#torch.cuda.is_available()

# %%
#torch._C.has_cuda

# %%
#pip install tensorflow-gpu

# %%
#!nvidia-smi
